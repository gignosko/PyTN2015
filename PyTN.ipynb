# %% [markdown]
# #iPython Notebook
# iPython is a great substitute for the standard python interpreter. It gives a lot of additional features including tab completetion, line numbers, a host of magic functions that do things like time the execution of your code, data visualization support and a more.
#
# iPython also has this handy notebook, which is a great way to:
# * Quickly edit and run code
# * Take rich notes using markdown so you can pass them on to others
# * Insert mathematical symbols using Latex
# * Use visualize data inline
#
# ## iPython Notebook quick tour
# * You write code or markdown in cells like this.
# * New cells default to code, but you can change it to a markdown cell using the drop down in the tool bar above.
# * If you write code, you can run it with Shift + Enter/Return
# * Each cell keeps its own history so if you change cell A, then change cell B, you can undo changes in A without upsetting B
# * New cells are added below by default, but you can move them up or down with the arrows in the tool bar.
# * You can run a cell or interrupt a long running execution with the tool bar, too.

# %%
import os
import json
import pandas as pd

# %% [markdown]
# These are my imports. You can put them all at the top like this, or you can scatter them throughout your code in various cells. Either way, once imported, the packages are available to every cell.
#
# Now, let's talk about data!

# %%
current_leg_df = pd.read_csv('/Users/daddy/pytn/bills/legislators-current.csv')
historic_leg_df = pd.read_csv('/Users/daddy/pytn/bills/legislators-historic.csv')
pd.options.display.max_columns = 50

# %% [markdown]
# Pandas is a great tool for manipulating and analyzing your data. The main data type in the pandas library is the Dataframe, 2D structure of rows and columns, like a spreadsheet but...fun.
#
# Pandas Dataframes have a variety of semantics for accessing and slicing your data. For the most part, these resemble access semantics for common python data types such as dictionaries, lists and tuples, but they also have a bit of syntactic sugar to make access a little easier and a lot more powerful.
#
# The above code reads csv files into some Dataframes for us to manipulate in a bit. And we've set the maximum column display size to 50 so we can potentially see above the default of 20.
#
# Dataframe columns are actually a pandas Series datatype, which is an N x 1 data structure. We'll see them a bit in this, but for the most part we'll stick to the Dataframes.

# %%
current_leg_df

# %% [markdown]
# We can see that pandas has given us a neat data structure from the csv file. And in the next cells we can see how easy it is to slice a Dataframe and query for specific values.

# %%
current_leg_df[:5]

# %%
current_leg_df[current_leg_df['last_name'] == 'Chu']

# %%
current_leg_df['party'].value_counts()

# %% [markdown]
# pandas can also read from a variety of file types, including json. But, there are some catches.

# %%
loc = r'/Users/daddy/pytn/bills/votes/2013/s10/data.json'
single_vote_df = pd.read_json(loc)
single_vote_df

# %%
single_vote_df.shape

# %% [markdown]
# Something is definitely off and looking at the shape of the Dataframe we can start to make some guesses about what. Reading a json file into a Dataframe requires some type of orientation so pandas knows what are column headings versus indexes and how the values should be filled in. The default orientation for Dataframes is by column, so when pandas reads the json, the first level keys become the column headings for the dataframe. The second level keys, if there are any, become the row indexes. Pandas will do its best to map the json values to an N x M matrix.
#
# Looking at the json file, there are 18 first level keys and 8 second level ones and the shape of the Dataframe lets us know that. So,  pandas has taken the first level of the json and turned it into columns and the turned the second level into rows. This isn't what we want, but it gives us a bit of a better insight into the data we have.
#
# The problem here is the shape of our json file. Because we have all the No votes clustered into a list and all the Aye votes clustered in a separate list, we'll need to dig in a little deeper into the json file and split it out. To do that we'll need to manually manipulate the file.

# %%
with open(loc) as json_file:
    json_data = json.load(json_file)  
    yes_df = pd.DataFrame(json_data['votes']['Aye'])
yes_df

# %%
with open(loc) as json_file:
    json_data = json.load(json_file)  
    no_df = pd.DataFrame(json_data['votes']['No'])
no_df

# %% [markdown]
# We can do that for each of the 4 vote types, but that leaves us with 4 Dataframes, so we'll need a way to put them all into one workable Dataframe. Luckily, Dataframes have a concatenate function that'll do this for us. We'll also want to add a column that records the vote for each person and that's pretty easy to accomplish: we'll add a new column in the same way that we would add a new entry in a dictionary.

# %%
no_df['vote'] = 'No'
yes_df['vote'] = 'Aye'
yes_no_df = pd.concat([no_df, yes_df])
yes_no_df

# %% [markdown]
# To get to the final Dataframe we need, we can keep using the techniques we've built up so far, grabbing the pieces of data we need from the legislators Dataframes, the votes Dataframes or a bills Dataframe that we haven't looked at. Since we're really more interested in the techniques than the actual data, I'll skip forward a bit and quickly go over how I built up the final Dataframe using these techniques.

# %%
#home = r'/Users/daddy/pytn/bills/'
votes = home + 'votes'
bills = home + 'bills'
votes_list = []
votes_df = pd.DataFrame()
counter = 0
for x in os.walk(votes):
    if x[2]:
        json_file = x[0] + '/' + x[2][0]
        json_data = open(json_file)
        all_data = json.load(json_data)
        
        if ('bill' in all_data) and ('amendment' not in all_data):
            bill_type = all_data['bill']['type']
            bill_number = bill_type + str(all_data['bill']['number'])
            bill_file = bills + '/' + bill_type + '/' + bill_number + '/data.json'
            with open(bill_file) as f:
                bill_json = json.load(f)
                sponsor_id = bill_json['sponsor']['thomas_id']
            sponsor_party = current_leg_df[current_leg_df['thomas_id'] == int(sponsor_id)]['party']
            if sponsor_party.values.size == 0:
                sponsor_party = historic_leg_df[historic_leg_df['thomas_id'] == int(sponsor_id)]['party']
            votes = all_data['votes']
            vote_id = all_data['vote_id']
            for k,v in votes.iteritems():
                df = pd.DataFrame(v)
                if sponsor_party.values:
                    df['sponsor_party'] = sponsor_party.values[0][0]
                else:
                    df['sponsor_party'] = 'U'
                df['vote'] = k
                df['bill'] = bill_number
                df['vote_id'] = vote_id
                votes_list.append(df)
            votes_df = pd.concat(votes_list)
    counter = counter + 1
votes_df.to_pickle('/Users/daddy/pytn/dataframe.pkl')

# %% [markdown]
# With a few thousand files to open, this process is pretty inefficient and you really don't want to have to rerun it to build a working Dataframe every time. Pandas gives you a couple of ways to save your Dataframes for later use including to_csv, to_json and to_pickle functions.

# %%
pickle_file = ('/Users/daddy/Dropbox/pytn/dataframe.pkl')
total_df = pd.read_pickle(pickle_file)
total_df

# %% [markdown]
# You'll notice here that the index resets because each of the Dataframes that we started with has it's own index and pandas doesn't automatically re-index on concatenation, but that's easy to fix if we need to.

# %%
total_df.index = range(1, len(total_df) +1)
total_df

# %% [markdown]
# Now that we've munged our data into something a bit more useful, let's start looking at it.
#
# Pandas lets you group your Dataframes by columns, much like you could in a pivot table. We can use groupby() to group our columns and then use count() to get some counts of the values. Let's play around with this a bit and see how we can drill in to get a better idea of the data.

# %%
total_df.groupby(['party'])['vote'].count()

# %%
total_df.groupby(['bill', 'vote_id','party'])['vote'].count()

# %%
vote_counts = total_df.groupby(['bill', 'vote_id', 'sponsor_party','party', 'vote'])['vote'].count()
vote_counts

# %%
type(vote_counts)

# %% [markdown]
# Looking at the type of the vote count results, we see that it's a Series. Remember, a Series is a Nx1 data structure, so it's really just a single column of data. The counts are the data, but the rest of what we see is a hierarchical index for each row.
#
# As it stands, the votes all exist in individual rows, but we want to pull them around and have them as column headings so we can can ultimately see all the Yes votes in one column, all the No votes in another, and so on. This hierarchical index is something we can grab and manipulate to let us reshape the data into something more useful.

# %%
new_df = total_df.loc[:, ['bill', 'vote_id','party', 'vote']]
new_df

# %% [markdown]
# First, we create a new Dataframe to work with because we only need a few of the columns from the total_df. To get specific columns, we can use the Dataframe.loc function, which grabs the rows or columsn by label name. So, total_df.loc[:,...] is a slice that says grab me all the rows while ..., ['bill', 'vote_id','party', 'vote']] says grab me those particular labels. This makes out new Dataframe.

# %%
new_df['counts'] = new_df.groupby(['vote_id','party','vote']).transform('count')
new_df
# Out:
#           bill        vote_id party        vote  counts
# 1       hr1120  h100-113.2013     D         Yea     197
# 2       hr1120  h100-113.2013     D         Yea     197
# 3       hr1120  h100-113.2013     D         Yea     197
# 4       hr1120  h100-113.2013     D         Yea     197
# 5       hr1120  h100-113.2013     D         Yea     197
# 6       hr1120  h100-113.2013     D         Yea     197
# 7       hr1120  h100-113.2013     D         Yea     197
# 8       hr1120  h100-113.2013     D         Yea     197
# 9       hr1120  h100-113.2013     D         Yea     197
# 10      hr1120  h100-113.2013     D         Yea     197
# 11      hr1120  h100-113.2013     D         Yea     197
# 12      hr1120  h100-113.2013     D         Yea     197
# 13      hr1120  h100-113.2013     D         Yea     197
# 14      hr1120  h100-113.2013     D         Yea     197
# 15      hr1120  h100-113.2013     D         Yea     197
# 16      hr1120  h100-113.2013     D         Yea     197
# ...

# %% [markdown]
# Transform applies a function to the groupby object and returns an object that has the same index as the one being grouped. So,  we pass the count function by name and we've added a new column that has a count of the votes by vote_id, party and vote. You can see that each row has the same count until one of those three keys changes.

# %%
temp_s1 = new_df.groupby(['vote_id','bill', 'party','vote'])['vote'].count()
temp_s1
# Out:
# vote_id        bill     party  vote
# h10-113.2014   hr2279   D      Aye             5
#                                No            184
#                                Not Voting     11
#                         R      Aye           220
#                                No              4
#                                Not Voting      8
# h100-113.2013  hr1120   D      Nay             1
#                                Not Voting      3
#                                Yea           197
#                         R      Nay           228
#                                Not Voting      3
# h100-113.2014  hres501  D      Nay           190
#                                Not Voting      8
#                                Yea             1
#                         R      Not Voting      7
# ...
# s93-113.2014  hr4302  I      Yea            2
#                       R      Nay           29
#                              Yea           16
# ...

# %%
temp_df2 = temp_s1.unstack()
temp_df2
# Out:
# vote                          Aye  Nay   No  Not Voting  Present  Yea
# vote_id       bill     party
# h10-113.2014  hr2279   D        5  NaN  184          11      NaN  NaN
#                        R      220  NaN    4           8      NaN  NaN
# h100-113.2013 hr1120   D      NaN    1  NaN           3      NaN  197
#                        R      NaN  228  NaN           3      NaN  NaN
# h100-113.2014 hres501  D      NaN  190  NaN           8      NaN    1
#                        R      NaN  NaN  NaN           7      NaN  224
# h101-113.2013 hr1120   D      NaN  NaN  199           2      NaN  NaN
#                        R      219  NaN   10           2      NaN  NaN
# h103-113.2013 hr1162   D      NaN  NaN  NaN          15      NaN  186
#                        R      NaN  NaN  NaN           9      NaN  222
# h104-113.2013 hr882    D      NaN  NaN  NaN          14      NaN  187
#                        R      NaN  NaN  NaN          11      NaN  220
# ...

# %% [markdown]
# Next, we create a series from that Dataframe, the same as we did above, so that the vote_id, bill, party and vote all make up a  unique index with the counts as the data values. Then, we unstack the Series index, which pulls the index apart and turns each hierarchical level into a column again, but this time, it takes the counts values with it and puts them in as data.
#
# But, we have a lot of NaN values in this Dataframe and that's going to mess us up later so let's change those to 0. pandas has a function fillna() that works on both Datframes and Series to fill in the NaN values with whatever value you pass as a function parameter. For reasons I can't explain, it does not work on the Dataframe we've created, so, we'll have to get a bit creative.

# %%
#this should work, but doesn't
temp_df2.fillna(0)
temp_df2
# Out:
# vote                          Aye  Nay   No  Not Voting  Present  Yea
# vote_id       bill     party
# h10-113.2014  hr2279   D        5    0  184          11        0    0
#                        R      220    0    4           8        0    0
# h100-113.2013 hr1120   D        0    1    0           3        0  197
#                        R        0  228    0           3        0    0
# h100-113.2014 hres501  D        0  190    0           8        0    1
#                        R        0    0    0           7        0  224
# h101-113.2013 hr1120   D        0    0  199           2        0    0
#                        R      219    0   10           2        0    0
# h103-113.2013 hr1162   D        0    0    0          15        0  186
#                        R        0    0    0           9        0  222
# h104-113.2013 hr882    D        0    0    0          14        0  187
#                        R        0    0    0          11        0  220
# ...

# %%
temp_df2 = temp_df2.replace(to_replace=float('nan'), value=0)

# %% [markdown]
# This line takes the Dataframe and calls the replace() function directly, passing in the value to replace (in this case a float of value nan) and the new value.
#
# Ok, let's start visualizing!

# %%
# %matplotlib inline
temp_df2[:10].plot(kind='bar', stacked=True)

# %% [markdown]
# matplotlib is the most widely used plotting library in python and the standard tool for plotting when working with pandas because it's integrated into the pandas library. Above, you can see that we've called the plot() function on a slice of our Dataframe, passed in the kind of plot we want and since it's a bar, told it to stack the values from each column. You can see that we've let pandas decide where to put the legend and it's obscuring out data. If we import matplotlib and manually construct this plot, then we can gain a bit more control over things. We'll do some of that below.
#
# Also notice the %matplotlib inline.  This tells iPython notebook to not only return the plot, but to also show it inline. Without that line, the function would return the plot object, but we wouldn't see the pretty pictures.
#
# As we're looking at this plot, something obvious stands out. We have a column for Yea and a column for Aye; likewise, we have a column for No and a column for Nay. Welcome to the Federal Government! Each House of Congress records it's votes differently, so we get two columns for the same answer. Let's fix that.

# %%
temp_df2['Y'] = temp_df2['Aye'].add(temp_df2['Yea'])
temp_df2['N'] = temp_df2['No'].add(temp_df2['Nay'])
temp_df2 = temp_df2.drop(['Aye', 'Yea', 'Nay', 'No', 'Not Voting', 'Present'], axis=1)
temp_df2
# Out:
# vote                            Y    N
# vote_id       bill     party
# h10-113.2014  hr2279   D        5  184
#                        R      220    4
# h100-113.2013 hr1120   D      197    1
#                        R        0  228
# h100-113.2014 hres501  D        1  190
#                        R      224    0
# h101-113.2013 hr1120   D        0  199
#                        R      219   10
# h103-113.2013 hr1162   D      186    0
#                        R      222    0
# h104-113.2013 hr882    D      187    0
#                        R      220    0
# h105-113.2013 hr249    D       35  152
#                        R      215    7
# h105-113.2014 hr3826   D      184    3
#                        R        0  220
# h106-113.2013 hr1163   D      194    0
#                        R      222    0
# h106-113.2014 hr3826   D       10  180
#                        R      219    3
# h107-113.2013 hr756    D      195    0
#                        R      207   16
# ...

# %%
temp_df2[:10].plot(kind='barh', stacked=True)

# %%
import matplotlib.pyplot as plt
import numpy as np
temp_df2['sum'] = temp_df2.sum(axis=1)
x = temp_df2['sum'].values 
y = np.square(x)
plt.ylabel('No votes')
plt.xlabel('Sum of all votes')
plt.scatter(x=x, y=y)

# %% [markdown]
# Here we've added a sum column by calling the sum() function and telling it to work across the columns. We've also imported matplotlib so we'll have better control over the plots and numpy so we can use some of it's math functions.
#
# We set the values of the sum column as the x axis and set y as a function of the square of x then added labels and made a scatter plot. And it's just that easy.

# %%
from scipy import stats
x = temp_df2['Y']
y = temp_df2['N']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
yp = np.polyval([slope, intercept],x)
plt.plot(x, yp)
plt.scatter(x,y)

# %% [markdown]
# And here if we import the scipy's stats library, we can get the values we need to do a linear regression of the No votes over the Yes votes.

# %%
temp_df2.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x127cba690>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1290a7250>]], dtype=object)

# %% [markdown]
# And of course, the ubiquitous histogram. In this case, pandas gives us one for each numeric column in the Dataframe. And below we see an interesting grouping of plots called a scatter matrix, which does a scatter plot of every column over every other column. Since the diagonals in this matrix would be a straight line (plotting a column over itself), the scatter_matrix function takes a diagonal parameter that lets us tell it what we want on the diagonal. In this case we're plotting the kernal desity estimate, which is roughly equivalent to a histogram, but with a smooth curve.

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(temp_df2, alpha=0.2, figsize=(10,10), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1297dc990>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x129c14150>]], dtype=object)

# %% [markdown]
# #Machine Learning
# Machine Learning falls into roughly two categories: supervised and unsupervised. We're going to look at a supervised method, which means that we will train the machine using input for which we already know the output. For input we have the party of the vote sponsor and the party of the voter and the output is the vote each voter cast. To get the data into the proper form for machine learning, we're going to go back to our total_df, but we need to drop some un-needed columns, clean out some data and  change what's left to numeric data. We'll be using a Perceptron for our learning algorithm and we can feed it the data in an "array like" structure, which would can be the Dataframe, but the target or results needs to be an actual array, so we'll have to split that off.
#
# Luckily for us, panda's Dataframes and Series are both built on top of numpy's ndarray. An ndarray is different from the standard python array in that the ndarray is an n-dimensional array, rather than a 1 dimensional array and ndarrays give us access to a lot of numpy's mathematical functions to use on the ndarray. As we'll see in a bit, we'll be using a matrix, which is just a 2D array that is a sub class of ndarray, to perform efficient matrix algebra.
#
# For now, what we need to do is pull the values out of the Dataframe and they will automatically be an ndarray, however the values will be be object datatypes, so we'll need to convert them to float64 because that's what the Perceptron requires. The data is represented as a float because it typically needs to be normalized to a value between 0 and 1; since we only have two values per input (Democrat or Republican), we can just go ahead and make them 0 and 1 for simplicity.  And, since the data can be in a Dataframe, we'll just change it in line.
#
# Let's start by creating our final Dataframe and dropping the unnecessary columns which is an easy task in pandas. We can create a list of column names we'd like to drop, then use that list as a parameter to the drop() function; we will also need to tell pandas if we are dropping columns or rows, so we'll set the index parameter to 1 for columns. For a bit of simplicity, w want to make sure we only have Democrats and Republicans (Sorry, Senator Sanders) and Yes or No votes.  We can tell pandas to re-create the Dataframe with vote values not equal to Present or Not Voting and with party and sponsor_party without I's.

# %%
drop_list = ['bill', 'display_name', 'first_name', 'id','last_name', 'state', 'vote_id']
final_df = total_df.drop(drop_list, axis=1)
final_df = final_df[final_df['vote'] != 'Present']
final_df = final_df[final_df['vote'] != 'Not Voting']
final_df = final_df[final_df['party'] != 'I']
final_df = final_df[final_df['sponsor_party'] != 'I']
final_df['vote'].value_counts()
# Out:
# Yea    160517
# Nay     60110
# Aye     45479
# No      36642
# dtype: int64

# %% [markdown]
# We can see that we have the same problem as earlier, which is both Yea and Aye for yes and Nay or No for no. We fixed it before pretty easily, but now we need to make two changes: combine all the yes/no values and convert them from text to numbers.

# %%
change_mapping = {'R': 0, 'D': 1, 'Nay': 0, 'No': 0, 'Yea': 1 , 'Aye': 1, 'Yes': 1}
final_df['sponsor_party'] = final_df['sponsor_party'].map(change_mapping)
final_df['party'] = final_df['party'].map(change_mapping)
final_df['vote'] = final_df['vote'].map(change_mapping)
final_df
# Out:
#         party  sponsor_party  vote
# 1           1              0     1
# 2           1              0     1
# 3           1              0     1
# 4           1              0     1
# 5           1              0     1
# 6           1              0     1
# 7           1              0     1
# 8           1              0     1
# 9           1              0     1
# 10          1              0     1
# 11          1              0     1
# 12          1              0     1
# 13          1              0     1
# 14          1              0     1
# 15          1              0     1
# 16          1              0     1
# 17          1              0     1
# 18          1              0     1
# 19          1              0     1
# 20          1              0     1
# 21          1              0     1
# 22          1              0     1
# 23          1              0     1
# 24          1              0     1
# 25          1              0     1
# 26          1              0     1
# ...

# %% [markdown]
# Now that everything is a number, we need to separate the votes out from the main Dataframe. When we pull a column off of a Dataframe, it becomes a Series object, but if we use the values() function on that Series, we get back an ndarray of the values, which is what we need, but they are the wrong data type; the Perceptron requires a float and the values we have are ints, so we'll take care of that, too by calling the ndarray's astype() function, which can cast all the ints to floats for us.  Finally, we'll call the ravel() function which flattens the ndarray from a N x 1 array into a 1 x N array.

# %%
target = final_df.take([2], axis=1)
target = target.values
target = target.astype('float64')
target = target.ravel()
target
# Out:
# array([ 1.,  1.,  1., ...,  0.,  0.,  0.])

# %% [markdown]
# #Perceptron
# In *A Brief History of Time* Stephen Hawking said that he was warned that for each equation he added, the readership would drop by half. I certainly hope that's not the case with this audience, but just in case, I'll speak in generalities and let the readers do their own research about the equations.
#
# A Perceptron is one of the earliest classifier algorithms, introduced by Frank Rosenblatt in 1958. The Perceptron is an Artifical Neural Network which is the name for a set of learning algorithms designed to imitate the way a neuron in the brain functions. In this case a number of inputs (for us that's the party of the sponsor and the party of the voter, so two) each get assigned a different weight. These products are then summed together and run through a step function, which will determine if the output is 1 or 0. There are other functions besides a step funtion that can be used (sign, sigmoid, and linear are the most common) but for single layer Perceptrons like this, the results are the same.
#
# Perceptrons are only able to classify solutions into one of two classes and they are only able to solve problems where those classes are lineraly separable, but for our purpses, that's fine since our model fits both of those criteria. To classify models that have more than two classes you would have to use a multilayer Perceptron, but that's not what we're going for here, so lets look at a pretty picture of a perceptron.

# %%
from IPython.display import Image
Image(filename='perceptron.png')

# %% [markdown]
# The Perceptron has to be trained to properly classify our input. At a basic level, the algorithm is fed some training data that has the inputs to be tested and a known output. The Perceptron adds the weights, combines the inputs, applies the step function and compares the output to the known solution. If the outputs don't match, the weights are adjusted slightly and the process starts again. The weights get adjusted according to an error function that determines if the calculated output is too big (1), too small (-1) or accurate (0). The weights then get adjusted up or down according to the error and another small variable called the learning rate, and the process starts all over again. The tricky part of the learning algorithm is that all the training rows contribute to the error calculation during each iteration, so the entrire learning set gets processed simultaneously.
#
# A really clear description of the entire Perceptron algorithm, complete with yummy equations can be found here:
# http://reference.wolfram.com/applications/neuralnetworks/NeuralNetworkTheory/2.4.0.html
#
# With that out of the way let's talk about how we could implement a Perceptron. An initial approach might be to take the algorithm at face value: initialize a set of weights for each input, loop through the inputs and multiply them by their weights, check the calculated output to the known output and then apply the contribution of that set of data to the error function. Then we put that whole big thing in a loop and do a few dozen more times until all the outputs are correct (or until we've reached some threshold for the number of times we want to loop through this. That ends up being a lot of looping and a lot of calculations to keep up with. Luckily, we have something that can help simplify this process: numpy's matrices.
# A matrix is exactly what we've been working with this entire time: a 2 dimensional arrangement of data into rows and columns. All the Dataframes that we've worked with are built from numpy ndarrays (n-dimensional arrays) and a matrix is a 2D array that lets us perform matrix algebra. In particular, we can use the matrix dot product to multiply the input values in all the rows by their weights simultaneously.

# %%
for n in range(nIterations):
    outputs =  where(dot(inputs,weights)>0,1,0)
    weights += eta*dot(transpose(inputs),targets-outputs)

# %% [markdown]
# As you can see in the code above, we've replaced some potentially hairy loops with a couple of matrix dot product calls, one that gives us all of our outputs in a single array and another that calculates our new weights and both in a single line that's easy on the eyes.
#
# Of course, this would be at the heart of a very stripped down Perceptron. We'd have to initialize the weights, work in a way to possibly shuffle the training data between iterations, build a confusion matrix (wait... a what?) and a small host of other things. So, why should we build our own easy, yet underpowered Perceptron, when there's one built right into scikit-learn?
#
# We'll

# %%
target = target.ravel()
target
# Out:
# array([ 1.,  1.,  1., ...,  0.,  0.,  0.])

# %%
data = final_df.drop('vote', axis=1)

# %%
from sklearn.linear_model import perceptron
from sklearn import cross_validation as cv
per = perceptron.Perceptron(n_iter=10, eta0=0.002)
data_train, data_test, target_train, target_test = cv.train_test_split(data, target)
per.fit(data_train, target_train)
print "Prediction " + str(per.predict(data_test))
print "Actual     " + str(target_test)
print "Accuracy   " + str(per.score(data_test, target_test)*100) + "%"
# Out:
# [ 0.  1.  1. ...,  1.  0.  1.]
# Prediction [ 1.  1.  0. ...,  0.  0.  0.]
# Actual     [ 1.  1.  1. ...,  1.  0.  0.]
# Accuracy   68.7383566531%

# %% [markdown]
# Here we've done several things. After our imports we instantiate a Perceptron with the number of iterations set to 10 and a learning rate (eta0) of 0.002; this can in theory help reduce the number of iterations the Perceptron needs. Often times we will have one set of data and we'll want to split it so we have a a training set and a testing set. sklearns's train_test_split function will do that for us, returning a pair of data and target arrays.

# %%
from sklearn.metrics import confusion_matrix
y_pred = per.predict(data_test)
cm = confusion_matrix(target_test, y_pred)
print cm
import matplotlib.pylab as plt
plt.matshow(cm)
plt.title('Confusion matrix')
plt.colorbar()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# [[15869  8358]
#  [15303 36157]]
